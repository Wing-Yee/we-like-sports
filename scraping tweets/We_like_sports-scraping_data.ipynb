# %%
'''
Requirements
pip install selenium==4.2.0
pip install Scweet==1.8  
pip install -r requirements.txt
https://github.com/Altimis/Scweet/blob/master/README.md
'''

# %%
from Scweet.scweet import scrape
from Scweet.user import get_user_information, get_users_following, get_users_followers
import pandas as pd

# %%
#list events you would like to compare

word_list_1 = [#"women's six nations",
    #"EFL Play-Off",
    #"EFL League",
    #"Rainbow Laces",
    #"Women's EURO",
    #"World Cup",
    #"Premiere League",
    #"Winter Olympics",
    #"Super Bowl",
    #"The Open",
    #"Invictus Games",
    #"Winter Paralympics",
    "Rugby World Cup",
    "World Athletics Championships",
    "Commonwealth Games",
    "Women’s Cricket World Cup",
    "Champions League Final",
    "Wimbledon",
    "Soccer Aid",
    "FA Cup Final",
    "Silverstone",
    "The Hundred",
    "Europa League Final",
    "Six Nations",
    "Carabao Cup Final",
    "AFCON",
    "Tour de France Femmes",
    "ICC World T20"]

# %%
#the scrape method will automatically name the csv keyword-date_from-date_to.csv 
#if your word list is too long it will fail, so we use a for loop to pull each event into its own csv file
#headless will open up a browser window, if its True the method will not work and the csv will be empty

# %%
for word in word_list_1:
    data = scrape(words=word, since="2022-01-01", until="2022-12-31", from_account = None,
            headless=False, save_images=False, 
              save_dir="/Users/admin/code/Wing-Yee/data-challenges/we_like_sports", interval=1,
              resume=False, filter_replies=True, proximity=False)
# Out:
# looking for tweets between 2022-01-01 and 2022-01-02 ...
#  path : https://twitter.com/search?q=(Rugby World Cup)%20until%3A2022-01-02%20since%3A2022-01-01%20%20-filter%3Areplies&src=typed_query
# scroll  1
# scroll  2
# Tweet made at: 2022-01-01T10:31:04.000Z is found.
# Tweet made at: 2022-01-01T08:09:32.000Z is found.
# Tweet made at: 2022-01-01T04:54:40.000Z is found.
# Tweet made at: 2022-01-01T14:00:01.000Z is found.
# Tweet made at: 2022-01-01T04:49:35.000Z is found.
# Tweet made at: 2022-01-01T02:49:17.000Z is found.
# Tweet made at: 2022-01-01T03:49:13.000Z is found.
# scroll  3
# scroll  4
# scroll  5
# looking for tweets between 2022-01-02 and 2022-01-03 ...
#  path : https://twitter.com/search?q=(Rugby World Cup)%20until%3A2022-01-03%20since%3A2022-01-02%20%20-filter%3Areplies&src=typed_query
# Tweet made at: 2022-01-02T13:31:12.000Z is found.
# scroll  1
# scroll  2
# scroll  3
# looking for tweets between 2022-01-03 and 2022-01-04 ...
# ...

# %%
df=pd.read_csv("/Users/admin/code/Wing-Yee/data-challenges/we_like_sports/football_2022-03-25_2022-03-27.csv")

# %%
df.head()
# Out:
#        UserScreenName         UserName                 Timestamp  \
# 0                  JM         @JongBVB  2022-03-25T23:12:54.000Z
# 1              Alexei  @MUFC_redarmy99  2022-03-25T23:04:55.000Z
# 2      Brennan Wooten  @brennan_wooten  2022-03-25T22:51:09.000Z
# 3       Ayden Schmidt   @AydenSchmidt3  2022-03-25T23:40:47.000Z
# 4  Garinger Athletics  @ghsathletics01  2022-03-25T23:32:01.000Z
#
#                                                 Text  \
# 0                      JM\n@JongBVB\n·\nMar 26, 2022
# 1           Alexei\n@MUFC_redarmy99\n·\nMar 26, 2022
# 2   Brennan Wooten\n@brennan_wooten\n·\nMar 26, 2022
# 3     Ayden Schmidt\n@AydenSchmidt3\n·\nMar 26, 2022
# 4  Garinger Athletics\n@ghsathletics01\n·\nMar 26...
#
#                                        Embedded_text Emojis  Comments  Likes  \
# 0  Borussia Dortmund - UCL 12/13 \n           Bea...      🤗       2.0   13.0
# 1  Such a shame that it turned out Cavani couldn’...    NaN       9.0   38.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   UserScreenName  50 non-null     object
#  1   UserName        51 non-null     object
#  2   Timestamp       55 non-null     object
#  3   Text            51 non-null     object
#  4   Embedded_text   52 non-null     object
#  5   Emojis          25 non-null     object
#  6   Comments        36 non-null     float64
#  7   Likes           51 non-null     float64
#  8   Retweets        51 non-null     object
#  9   Image link      55 non-null     object
#  10  Tweet URL       55 non-null     object
# dtypes: float64(2), object(9)
# memory usage: 4.9+ KB
